# %% [markdown]
# # Chatbot Test Version

# %% [markdown]
# We first import the necessary materials we will need to create the chat bot that is rasa_nlu,rasa_coreand the required langiage of the chatbot

# %%
import rasa_nlu
import rasa_core
import spacy

# %%
print("rasa_nlu: {} rasa_core: {}".format(rasa_nlu.__version__, rasa_core.__version__))
# Out:
# rasa_nlu: 0.15.1 rasa_core: 0.14.5

# %% [markdown]
# load the required language ofthe bot

# %%
print(spacy.load("en")("Hello world!"))
# Out:
# Hello world!

# %% [markdown]
# ## creation of  the  training data

# %% [markdown]
# ###  Intent
# It  is what the user is aiming for. For example if the user says Reserve a table at Cliff House tonight the intent can be classified as to book the table
#
# ### Entity
#
# It is to extract the useful information from the user input. From the example above Reserve a table at Cliff House tonight, the entities extracted would be place and time. Place is from Cliff House and Time is from tonight.
#
# we will create training tdata that will be used into to train our natural language model about intent clasiification and entity extraction

# %%
nlu_md = """

## intent:explain
- tell me more
- could you please explain that
- could you tell me more
- give me more information please
- could you please give me some more information
- i want more information
- what is the difference
- can you tell me the difference
- why
- why is that
- why do you need it
## intent:nicetomeeyou
- It’s great connecting with you.
- Hi, nice to meet you!
- Glad to meet you!
- Glad we've met.
- Lovely to meet you.
- Glad to meet you.
- It's nice to finally meet you.
- I am glad I met you.
- Hi Sara, just wanted to test you
- I am glad he introduced us.
- Glad to make your acquaintance.
- Great to meet you!
- I'm pleased to meet you!
- I'm happy that we have met!
- nice to meet you
- It's great to get to know you!
- I had a great meeting with you
- Pleased to meet you!
- Hi, glad to meet you.
- It’s a pleasure to meet you
- It's wonderful to meet you!
- Thank you for this meeting. It was great to see you.
- Feels great to see you!
- It's a pleasure to meet you!
- It is indeed a pleasure to be able to meet you.
- Great seeing you

## intent:thank
- Thanks
- Thank you
- Thank you so much
- Thanks bot
- Thanks for that
- cheers
- cheers bro
- ok thanks!
- perfect thank you
- thanks a bunch for everything
- thanks for the help
- thanks a lot
- amazing, thanks
- cool, thanks
- cool thank you
- thanks
- thanks!
- Cool. Thanks
- thanks
- thanks this is great news
- thank you
- great thanks
- Thanks!
- cool thanks
- thanks for forum link, I'll check it out

## intent:react_positive
- you are funny
- thats funny
- you are cool man
- you are doin great
- you are a badass bot!
- happy
- that was a great interaction
- i am happy
- i am happy today
- :)
- Wow
- You're really cool
- you seem pretty cool :D
- Lol
- hAHAHA
- today was a nice day
- lol
- you are awesome
- I am happy
- You're nice.
- ha ha
- HAHA
- i am very happy with your response
- You are great
- i love that
- you are cool
- that is funny
- it's pretty cool
- I'm glad to have met you!
- It's good that I could meet you. It was a pleasure.
- It was nice to have discuss with you
- Good to meet you!
- I'm thrilled to meet you!
- Happy to meet you.
- Pleased to meet you.
- It's great to make your acquaintance!
- Great interacting with you
- Delighted to make your acquaintance.
- I'm glad to meet you!
- Great to meet you.
- Nice to have met you.

## intent:affirm
- yes
- of course
- sure
- yeah
- ok
- cool
- go for it
- yep
- yep, will do thank you
- I'm sure I will!
- oh awesome!
- Yes
- accept
- I accept
- i accept
- ok i accept
- I changed my mind. I want to accept it
- ok cool
- alright
- i will!
- ok, I behave now
- yop
- oki doki
- yes please
- yes please!
- yep if i have to
- amayzing
- confirm
- nice
- definitely yes without a doubt
- yup
- perfect
- sure thing
- absolutely
- Oh, ok
- Sure
- sure!
- yes i accept
- amazing!
- how nice!
- cool!
- great
- oh cool
- yes
- fine

## intent:greet
- Hi
- Hey
- Hi bot
- Hey bot
- Hello
- Good morning
- hi again
- hi Mister
- hi pal!
- hi there
- greetings
- hello everybody
- hello is anybody there
- hello robot
- hallo
- heeey
- hi hi
- hey
- hey hey
- hello there
- hi
- hello
- yo
- hola
- hi?
- hey bot!
- hello friend
- good morning
- hii
- hello sweet boy
- hey there
- hiihihi
- ayyyy what's up
- hello?
- good evening
- good morning
- good afternoon


## intent:deny
- no
- definitely not
- never
- absolutely not
- i don't think so
- i'm afraid not
## intent:leaving
- leaving
- talk to you soon
- have to go
- got to go
- talk to you later
- heading out
- T'm leaving now
- going out


## intent:bye
- goodbye
- good bye
- good night
- see ya
- bye bye
- catch you later
- bye for now
- bye
- it was nice talking to you
- bye bye bot
- bye bot
- talk to you later


## intent:mood_happy
-  I am happy
-  I feel great
-  I'm fine
-  I had a great day

## intent:mood_unhappy
-  I am sad
-  I don't feel very well
-  I am disappointed
-  my day was horrible


## intent:find
- find
- i'm looking for
- help me find


## intent:please
- please
- plz
- pls
## intent: occurence
- How to I get information about the upcoming [events](occurence)
- How to I get information about the upcoming [events](occurence)
- How to I get information about the upcoming [contest](occurence)
- How to I get information about the upcoming [affair](occurence)
- How to I get information about the upcoming [business](occurence)
- How to I get information about the upcoming [occassion](occurence)
= How to I get information about the upcoming [occurence](occurence),please
## intent;meeting 
- How to I get information about the upcoming [gathering](meeting)
- How to I get information about the upcoming [meeting](meeting)
- How to I get information about the upcoming [conference](meeting), please
- How to I get information about the upcoming [congregation](meeting), please
- How to I get information about the upcoming [convocation](meeting)
- How to I get information about the upcoming [conclave](meeting)
- How to I get information about the upcoming [convention](meeting),pleas
- How to I get information about the upcoming [summit](meeting)
- How to I get information about the upcoming [forum](meeting)
- How do I get information about the next [meeting](meeting)
- How can I obtain information about the [conference](meeting)
- How do I get information about the coming [gathering](meeting)
## intent:data
- where can I find [information](data) about the chamber of commerce events' ?
-  where can I find [information](data) about the chamber of commerce events' ?
## intent: location
- The chamber of commerce, industries, mining and crafting (CCIMC) is a national consultative and representative body at the national services of the
entire [Cameroon](location) enterprises sector.
- The chamber of commerce, industries, mining and crafting (CCIMC) is a national advisory and representative body at the national services of the
entire [Cameroon](location) enterprises sector.  
- The chamber of commerce, industries, mining and crafting (CCIMC) is a national consultative and legislative body for the national services of the national services of the
entire [Cameroon](location) enterprises sector.
- The chamber of commerce, industries, mining and crafting (CCIMC) is a national consultative and legislative body for the national services of the national services of the
entire [Cameroon](location) business sector.



## intent:query_helping
- What can I help you with today?
- May I help you?
- What can I do for you?
- can I hekp you?
- yes,what can I do for You?
- any question
- May I assist you? 
- Perhaps I can help you? 
- How can I assist you?
- how can I help you?
- What can I do today to help you?



## intent:query_organisation
- What does the [Chamber of Commerce](Organisation) do?
- What does the [Chamber of Commerce,Industry, Mines and Crafts](Organisation) do?
- What does the [Cameroon Chamber of Commerce](Organisation) do?
- What does the [CCIMA](Organisation) do?
- What does the [CCIMC](Organisation) do?
- What is the [Chamber of Commerce](Organisation)?
- What is the [CCIMA](Organisation)?
- What is the [CCIMC](Organisation)?
- What is the [Chamber of Commerce,Industry, Mines and Crafts](Organisation)?
-- What is the [Cameroon Chamber of Commerce](Organisation)?

## intent:query_attend_per_organisation
- Who can attend [Cameroon Chamber of Commerce](Organisation) events?
- Who can attend [Chamber of Commerce,Industry, Mines and Crafts](Organisation) events?
- Who can attend [Chamber of comerce](Organisation) events?
- Who can attend [CCIMA](Organisation) events?
- Who can attend [CCIMC](Organisation) events?

## intent:query_infoattend_organisation
- Can you send an email to [CCIMA](Organisation) about an event you which to attain?
- How can I get [CCIMA](Organisation) event's?
- How can I get [chamber’s of commerce](Organisation) event's?
- How can I get [chamber’s of commerce](Organisation) event's?
- How can I get [Chamber of Commerce,Industry, Mines and Crafts](Organisation) event's?
- How can I get  [Cameroon](country) [chamber’s of commerce](Organisation) event's?
- Can you send an email to the [Chamber of commerce](Organisation) about an event?
- where can I find information about the [chamber of commerce](Organisation) events' ?
- where can I find information about [CCIMA](Organisation) events?
- Who can attend [CCIMC](Organisation) events?
- Can you send an email to [CCIMC](Organisation) about an event you which to attain?
- How can I get [CCIMC](Organisation) event's?
- where can I find information about [CCIMC](Organisation) events' ?
- How can I get [Chamber of Commerce,Industry, Mines and Crafts](Organisation)  event's?
- where can I find information about [Chamber of Commerce,Industry, Mines and Crafts](Organisation)  events' ?
- How can I get [Cameroon chamber’s of commerce](Organisation) event's?
- where can I find information about [Cameroon chamber’s of commerce](Organisation) events' ?

## intent:query_join_organisation
- how can I join the [chamber of commerce](Organisation)?
- how can I join the [Chamber of Commerce,Industry, Mines and Crafts](Organisation) ?
- how can I join the [Cameroon chamber of commerce](Organisation)?
- how can I join [CCIMA](Organisation)?
- how can I join [CCIMC](Organisation)?

## intent:query_list_organisation
- can I have the list of businesses registered at the [chamber of commerce](Organisation)?
- can I have the list of business registered at [CCIMA](Organisation)?
- can I have the list of business registered at [CCIMC](Organisation)?
- can I have the list of businesses registered at the [chamber of commerce](Organisation)?

## intent:query_services_organisation
- What are the services offered by the [Chamber of Commerce](Organisation)?
- What does the [Chamber of Commerce](Organisation) offered?


## intent:query_location_organisation
- Where is the [Chamber of Commerce](Organisation) located?
- Where is the [Chamber of Commerce](Organisation) located in [Cameroon](country)?

## intent:query_document1_organisation
- What is a [Consular file] (document)?
- How do we produce a [Consular file](document) ?
- Why do we need to produce [consular file](document)?


## intent:query_document2_organisation
- What is the [certificate of origin](document)?
- What is a  [certificate of origin](document)?
- What is meaning [certificate of origin](document)?
- What is the use  [certificate of origin](document)?

## intent:query_offeerdocument1_organisation
- Is the [Chamber of Commerce](Organisation) delivering [Certificate of origin](document)?
- who is in charge of giving [certificate of origin](document) 

## intent:query_invest_organisation
- How to access the [investor](person) opportunities?
- where can I find [investor](person) opportunities?
- where can I find some potential [investor](person) 
## intent:query_economic
- how to get the economic information of the country?
- how to get the economic information of the [cameroon](country) ?
- where can i have get the economic information of the country?
- where can i have get the economic information done by the [chamber of commerce](Organisation) ?
- I need economic information of [Cameroon](country)

## intent:query_support
- Can the [chamber of Commerce](Organisation) support you in creating an industry or a business?
- Can the [ccima](Organisation) support you in creating an industry or a business?
- Can the [ccimc](Organisation) support you in creating an industry or a business?
- Does the [chamber of Commerce](Organisation) support you in creating an industry or a business?
- Does the [ccima](Organisation) support you in creating an industry or a business?
- Does the [ccimc](Organisation) support you in creating an industry or a business?






## intent:explain
- tell me more
- could you please explain that
- could you tell me more
- give me more information please
- could you please give me some more information
- i want more information
- what is the difference
- can you tell me the difference
- why
- why is that
- why do you need it
## intent:nicetomeeyou
- It’s great connecting with you.
- Hi, nice to meet you!
- Glad to meet you!
- Glad we've met.
- Lovely to meet you.
- Glad to meet you.
- It's nice to finally meet you.
- I am glad I met you.
- Hi Sara, just wanted to test you
- I am glad he introduced us.
- Glad to make your acquaintance.
- Great to meet you!
- I'm pleased to meet you!
- I'm happy that we have met!
- nice to meet you
- It's great to get to know you!
- I had a great meeting with you
- Pleased to meet you!
- Hi, glad to meet you.
- It’s a pleasure to meet you
- It's wonderful to meet you!
- Thank you for this meeting. It was great to see you.
- Feels great to see you!
- It's a pleasure to meet you!
- It is indeed a pleasure to be able to meet you.
- Great seeing you

## intent:thank
- Thanks
- Thank you
- Thank you so much
- Thanks bot
- Thanks for that
- cheers
- cheers bro
- ok thanks!
- perfect thank you
- thanks a bunch for everything
- thanks for the help
- thanks a lot
- amazing, thanks
- cool, thanks
- cool thank you
- thanks
- thanks!
- Cool. Thanks
- thanks
- thanks this is great news
- thank you
- great thanks
- Thanks!
- cool thanks
- thanks for forum link, I'll check it out

## intent:react_positive
- you are funny
- thats funny
- you are cool man
- you are doin great
- you are a badass bot!
- happy
- that was a great interaction
- i am happy
- i am happy today
- :)
- Wow
- You're really cool
- you seem pretty cool :D
- Lol
- hAHAHA
- today was a nice day
- lol
- you are awesome
- I am happy
- You're nice.
- ha ha
- HAHA
- i am very happy with your response
- You are great
- i love that
- you are cool
- that is funny
- it's pretty cool
- I'm glad to have met you!
- It's good that I could meet you. It was a pleasure.
- It was nice to have discuss with you
- Good to meet you!
- I'm thrilled to meet you!
- Happy to meet you.
- Pleased to meet you.
- It's great to make your acquaintance!
- Great interacting with you
- Delighted to make your acquaintance.
- I'm glad to meet you!
- Great to meet you.
- Nice to have met you.

## intent:affirm
- yes
- of course
- sure
- yeah
- ok
- cool
- go for it
- yep
- yep, will do thank you
- I'm sure I will!
- oh awesome!
- Yes
- accept
- I accept
- i accept
- ok i accept
- I changed my mind. I want to accept it
- ok cool
- alright
- i will!
- ok, I behave now
- yop
- oki doki
- yes please
- yes please!
- yep if i have to
- amayzing
- confirm
- nice
- definitely yes without a doubt
- yup
- perfect
- sure thing
- absolutely
- Oh, ok
- Sure
- sure!
- yes i accept
- amazing!
- how nice!
- cool!
- great
- oh cool
- yes
- fine

## intent:greet
- Hi
- Hey
- Hi bot
- Hey bot
- Hello
- Good morning
- hi again
- hi Mister
- hi pal!
- hi there
- greetings
- hello everybody
- hello is anybody there
- hello robot
- hallo
- heeey
- hi hi
- hey
- hey hey
- hello there
- hi
- hello
- yo
- hola
- hi?
- hey bot!
- hello friend
- good morning
- hii
- hello sweet boy
- hey there
- hiihihi
- ayyyy what's up
- hello?
- good evening
- good morning
- good afternoon


## intent:deny
- no
- definitely not
- never
- absolutely not
- i don't think so
- i'm afraid not
## intent:leaving
- leaving
- talk to you soon
- have to go
- got to go
- talk to you later
- heading out
- T'm leaving now
- going out


## intent:bye
- goodbye
- good bye
- good night
- see ya
- bye bye
- catch you later
- bye for now
- bye
- it was nice talking to you
- bye bye bot
- bye bot
- talk to you later


## intent:mood_happy
-  I am happy
-  I feel great
-  I'm fine
-  I had a great day

## intent:mood_unhappy
-  I am sad
-  I don't feel very well
-  I am disappointed
-  my day was horrible


## intent:find
- find
- i'm looking for
- help me find


## intent:please
- please
- plz
- pls
## intent: occurence
- How to I get information about the upcoming [events](occurence)
- How to I get information about the upcoming [events](occurence)
- How to I get information about the upcoming [contest](occurence)
- How to I get information about the upcoming [affair](occurence)
- How to I get information about the upcoming [business](occurence)
- How to I get information about the upcoming [occassion](occurence)
= How to I get information about the upcoming [occurence](occurence),please
## intent;meeting 
- How to I get information about the upcoming [gathering](meeting)
- How to I get information about the upcoming [meeting](meeting)
- How to I get information about the upcoming [conference](meeting), please
- How to I get information about the upcoming [congregation](meeting), please
- How to I get information about the upcoming [convocation](meeting)
- How to I get information about the upcoming [conclave](meeting)
- How to I get information about the upcoming [convention](meeting),pleas
- How to I get information about the upcoming [summit](meeting)
- How to I get information about the upcoming [forum](meeting)
- How do I get information about the next [meeting](meeting)
- How can I obtain information about the [conference](meeting)
- How do I get information about the coming [gathering](meeting)
## intent:data
- where can I find [information](data) about the chamber of commerce events' ?
-  where can I find [information](data) about the chamber of commerce events' ?
## intent: location
- The chamber of commerce, industries, mining and crafting (CCIMC) is a national consultative and representative body at the national services of the
entire [Cameroon](location) enterprises sector.
- The chamber of commerce, industries, mining and crafting (CCIMC) is a national advisory and representative body at the national services of the
entire [Cameroon](location) enterprises sector.  
- The chamber of commerce, industries, mining and crafting (CCIMC) is a national consultative and legislative body for the national services of the national services of the
entire [Cameroon](location) enterprises sector.
- The chamber of commerce, industries, mining and crafting (CCIMC) is a national consultative and legislative body for the national services of the national services of the
entire [Cameroon](location) business sector.



## intent:query_helping
- What can I help you with today?
- May I help you?
- What can I do for you?
- can I hekp you?
- yes,what can I do for You?
- any question
- May I assist you? 
- Perhaps I can help you? 
- How can I assist you?
- how can I help you?
- What can I do today to help you?



## intent:query_organisation
- What does the [Chamber of Commerce](Organisation) do?
- What does the [Chamber of Commerce,Industry, Mines and Crafts](Organisation) do?
- What does the [Cameroon Chamber of Commerce](Organisation) do?
- What does the [CCIMA](Organisation) do?
- What does the [CCIMC](Organisation) do?
- What is the [Chamber of Commerce](Organisation)?
- What is the [CCIMA](Organisation)?
- What is the [CCIMC](Organisation)?
- What is the [Chamber of Commerce,Industry, Mines and Crafts](Organisation)?
-- What is the [Cameroon Chamber of Commerce](Organisation)?

## intent:query_attend_per_organisation
- Who can attend [Cameroon Chamber of Commerce](Organisation) events?
- Who can attend [Chamber of Commerce,Industry, Mines and Crafts](Organisation) events?
- Who can attend [Chamber of comerce](Organisation) events?
- Who can attend [CCIMA](Organisation) events?
- Who can attend [CCIMC](Organisation) events?

## intent:query_infoattend_organisation
- Can you send an email to [CCIMA](Organisation) about an event you which to attain?
- How can I get [CCIMA](Organisation) event's?
- How can I get [chamber’s of commerce](Organisation) event's?
- How can I get [chamber’s of commerce](Organisation) event's?
- How can I get [Chamber of Commerce,Industry, Mines and Crafts](Organisation) event's?
- How can I get  [Cameroon](country) [chamber’s of commerce](Organisation) event's?
- Can you send an email to the [Chamber of commerce](Organisation) about an event?
- where can I find information about the [chamber of commerce](Organisation) events' ?
- where can I find information about [CCIMA](Organisation) events?
- Who can attend [CCIMC](Organisation) events?
- Can you send an email to [CCIMC](Organisation) about an event you which to attain?
- How can I get [CCIMC](Organisation) event's?
- where can I find information about [CCIMC](Organisation) events' ?
- How can I get [Chamber of Commerce,Industry, Mines and Crafts](Organisation)  event's?
- where can I find information about [Chamber of Commerce,Industry, Mines and Crafts](Organisation)  events' ?
- How can I get [Cameroon chamber’s of commerce](Organisation) event's?
- where can I find information about [Cameroon chamber’s of commerce](Organisation) events' ?

## intent:query_join_organisation
- how can I join the [chamber of commerce](Organisation)?
- how can I join the [Chamber of Commerce,Industry, Mines and Crafts](Organisation) ?
- how can I join the [Cameroon chamber of commerce](Organisation)?
- how can I join [CCIMA](Organisation)?
- how can I join [CCIMC](Organisation)?

## intent:query_list_organisation
- can I have the list of businesses registered at the [chamber of commerce](Organisation)?
- can I have the list of business registered at [CCIMA](Organisation)?
- can I have the list of business registered at [CCIMC](Organisation)?
- can I have the list of businesses registered at the [chamber of commerce](Organisation)?

## intent:query_services_organisation
- What are the services offered by the [Chamber of Commerce](Organisation)?
- What does the [Chamber of Commerce](Organisation) offered?


## intent:query_location_organisation
- Where is the [Chamber of Commerce](Organisation) located?
- Where is the [Chamber of Commerce](Organisation) located in [Cameroon](country)?

## intent:query_document1_organisation
- What is a [Consular file] (document)?
- How do we produce a [Consular file](document) ?
- Why do we need to produce [consular file](document)?


## intent:query_document2_organisation
- What is the [certificate of origin](document)?
- What is a  [certificate of origin](document)?
- What is meaning [certificate of origin](document)?
- What is the use  [certificate of origin](document)?

## intent:query_offeerdocument1_organisation
- Is the [Chamber of Commerce](Organisation) delivering [Certificate of origin](document)?
- who is in charge of giving [certificate of origin](document) 

## intent:query_invest_organisation
- How to access the [investor](person) opportunities?
- where can I find [investor](person) opportunities?
- where can I find some potential [investor](person) 
## intent:query_economic
- how to get the economic information of the country?
- how to get the economic information of the [cameroon](country) ?
- where can i have get the economic information of the country?
- where can i have get the economic information done by the [chamber of commerce](Organisation) ?
- I need economic information of [Cameroon](country)

## intent:query_support
- Can the [chamber of Commerce](Organisation) support you in creating an industry or a business?
- Can the [ccima](Organisation) support you in creating an industry or a business?
- Can the [ccimc](Organisation) support you in creating an industry or a business?
- Does the [chamber of Commerce](Organisation) support you in creating an industry or a business?
- Does the [ccima](Organisation) support you in creating an industry or a business?
- Does the [ccimc](Organisation) support you in creating an industry or a business?







"""

# %store nlu_md > nlu.md
# Out:
# Writing 'nlu_md' (str) to file 'nlu.md'.

# %% [markdown]
# ## Creation of the pipeline

# %% [markdown]
# we will creat the pipeline in which we will train the training data. In rasa there three already define t pipelines are  supervised_embeddings , pretrained_embeddings_convert and pretrained_embeddings_spacy. The pretrained_embeddings_spacy pipeline uses pre-trained word vectors from either GloVe or fastText, whereas pretrained_embeddings_convert uses a pretrained sentence encoding model ConveRT to extract vector representations of complete user utterance as a whole. On the other hand, the supervised_embeddings pipeline doesn’t use any pre-trained word vectors or sentence vectors, but instead fits these specifically for your dataset.
#
#  pretrained_embeddings_convert is good foer the creation of a momlingual bot and pretrained_embeddings_convert is good to creat a bot with two languages, supervised_embeddings does not use any specific pre-defined pipeline. THe cde to compare the three different pipelines is "rasa test nlu --config pretrained_embeddings_spacy.yml supervised_embeddings.yml --nlu data/nlu.md --runs 3 --percentages 0 25 50 70 90"
#
#  other pipelines rarely used are MITIE, Class imbance and Multiple intents.
#
#  Here I have decide to create a Monlingual bot first using pretrained_embeddings_spacy, bu we to note that intent classification is independent of entity extraction that is NLU may get the intent right but entities wrong and vice versa
#
#
#  ### pretrained_embeddings_spacy
#  which is composed of the folowing
#
#  ### SpacyNLP
#  Initializes spacy structures. Every spacy component relies on this then it  should be put at the beginning of every pipeline that uses any spacy components. you can also used MitieNLP. Has the following use
#
#   - language model to load
#
#   - when retrieving word vectors, this will decide if the casing of the word is relevant. E.g. `hello` and `Hello` willretrieve the same vector, if set to `false`. For some applications and models it makes sense to differentiate between these two words, therefore setting this to `true`. case_sensitive: false
#
# ### SpacyTokenizer
# it is used in  breaking sentence into pieces(word), called tokens.
# ### SpacyFeaturizer
# appends its features to an existing feature vector generated by another intent featurizer. Decide whether to use word vector on CRFEntityExtractor.
# ### RegexFeaturizer
#  As sort of facilitationn of the intent and entity extractor.
#
#  ### CRFEntityExtractor
#  The CRFEntityExtractor is the technique used for entity extractor.
#  This component implements conditional random fields to do named entity recognition. Features of the words (capitalisation, POS tagging, etc.) give probabilities to certain entity classes, as are transitions between neighbouring entity tags: the most likely set of tags is then calculated and returned.
#
#
# ###    EntitySynonymMapper
# it modifies existing entities that previous entity extraction components has found.
#
#
# ### SklearnIntentClassifier
#
# The sklearn intent classifier trains a linear SVM which gets optimized using a grid search. In addition to other classifiers. This featurizer creates the features used for the classification.
#
#   Specifies the list of regularization values to cross-validate over for C-SVM. This is used with the ``kernel`` hyperparameter in GridSearchCV.
#
#   C: [1, 2, 5, 10, 20, 100]
#
# Specifies the kernel to use with C-SVM. This is used with the ``C`` hyperparameter in GridSearchCV.
#
#   kernels: ["linear"]

# %%
config = """
language: "en"

pipeline:                        #this is the pretrained_embeddings_spacy
- name: "SpacyNLP"
  model: "en_core_web_md"
  case_sensitive: 
- name: "SpacyTokenizer"
- name: "SpacyFeaturizer"
  ner_feature_vectors: True        # use word vector on ner_featuring
- name: "RegexFeaturizer"
- name: "CRFEntityExtractor"
  max_iterations: 50             # This is the value given to sklearn_crfcuite.CRF tagger before training
- name: "EntitySynonymMapper"
- name: "SklearnIntentClassifier"
  C: [1, 2, 5, 10, 20, 100]      # use grid search
  kernels: ["linear"]            # defint the kernel ton use 




policies:
  - name: KerasPolicy
  - name: MemoizationPolicy

""" 

# %store config > config.yml
# Out:
# Writing 'config' (str) to file 'config.yml'.

# %% [markdown]
# # Training data

# %% [markdown]
# Here we will train the dataset that (nlu.md)
#
# The train() function above in the Trainer model gets the training_data and iterates through it to generate a spaCy model. This is returned as the interpertor, which can interpret the input data and give structured data output.
#
# persistor fuction that is persists is a function that  store the data

# %%
from rasa_nlu.training_data import load_data
from rasa_nlu.config import RasaNLUModelConfig
from rasa_nlu.model import Trainer
from rasa_nlu import config
from rasa_nlu.model import Interpreter


# loading the nlu training samples
training_data = load_data("nlu.md")
# trainer to educate our pipeline
trainer = Trainer(config.load("config.yml"))
    # train the model!
interpreter = trainer.train(training_data, verbose=True)
# Returns the directory the model is stored in
model_directory = trainer.persist("./models/nlu", fixed_model_name="test3")
# Out:
# INFO:rasa_nlu.training_data.loading:Training data format of nlu.md is md
# INFO:rasa_nlu.training_data.training_data:Training data stats:
# 	- intent examples: 328 (30 distinct intents)
# 	- Found intents: 'query_list_organisation', 'leaving', 'mood_happy', 'affirm', 'query_document2_organisation', 'query_support', 'query_organisation', 'data', 'nicetomeeyou', 'deny', 'query_helping', 'greet', 'query_offeerdocument1_organisation', 'find', 'mood_unhappy', 'query_invest_organisation', 'query_attend_per_organisation', 'bye', 'location', 'query_join_organisation', 'please', 'query_services_organisation', 'thank', 'occurence', 'query_economic', 'query_infoattend_organisation', 'query_document1_organisation', 'react_positive', 'query_location_organisation', 'explain'
# 	- entity examples: 85 (7 distinct entities)
# 	- found entities: 'meeting', 'country', 'Organisation', 'document', 'person', 'data', 'occurence'
#
# ...

# %% [markdown]
# Here were are trying to produce the prediction of certain phrase of it's intent and entities

# %%
import logging, io, json, warnings
logging.basicConfig(level="INFO")
warnings.filterwarnings('ignore')
def xprint(o):
    # small helper to make dict dumps a bit prettier
    print(json.dumps(o, indent=2))
xprint(interpreter.parse(" how can I join CCIMC Organisation ?"))
# Out:
# {
#   "intent": {
#     "name": "query_join_organisation",
#     "confidence": 0.16464133756115648
#   },
#   "entities": [
#     {
#       "start": 16,
#       "end": 21,
#       "value": "ccimc",
#       "entity": "Organisation",
#       "confidence": 0.8679901357890355,
#       "extractor": "CRFEntityExtractor"
#     }
#   ],
#   "intent_ranking": [
#     {
#       "name": "query_join_organisation",
#       "confidence": 0.16464133756115648
#     },
#     {
#       "name": "affirm",
#       "confidence": 0.14313351309590555
#     },
#     {
#       "name": "query_infoattend_organisation",
#       "confidence": 0.12469598395493629
#     },
#     {
#       "name": "query_helping",
#       "confidence": 0.05515370885999379
#     },
#     {
#       "name": "greet",
#       "confidence": 0.04776068286417829
#     },
#     {
#       "name": "react_positive",
#       "confidence": 0.03890020202044369
#     },
#     {
#       "name": "occurence",
#       "confidence": 0.03324099666921695
# ...

# %% [markdown]
# Our model has predicted this text with a confidence of 16 percent of inetent and  85 percent of entity. we see that our intent are not well trained  this may due to the small amount of data

# %% [markdown]
# # Dialogue Management

# %% [markdown]
# here we will define the define stories and domain data that will be use to train the dialogie
#
# ### stories
#  here we will  create the stories that we will want our bot to freproduce

# %%
stories_md = """

## path 1               
* greet
  - utter_greet 
* query_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye

## path 2               
* greet
  - utter_greet 
* query_organisation{"Organisation":"CCIMC"} 
  - utter_action_query_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye

## path 3               
* greet
  - utter_greet 
* query_organisation{"Organisation":"Chamber of Commerce"} 
  - utter_action_query_organisation
* query_attend_per_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_attend_per_organisation
* query_infoattend_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_infoattend_organisation
* query_join_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_join_organisation
* query_services_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_services_organisation
* query_location_organisation{"Organisation":"CCIMA", "country":"Cameroon"} 
  - utter_action_query_location_organisation
* query_document1_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_document1_organisation
* query_document2_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_document2_organisation
* query_economic{"Organisation":"CCIMA"} 
  - utter_action_query_economic
* query_invest_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_invest_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye
  
## path 4               
* greet
  - utter_greet 
* query_attend_per_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_attend_per_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye

## path 5               
* greet
  - utter_greet 
* query_attend_per_organisation{"Organisation":"CCIMC"} 
  - utter_action_query_attend_per_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye

## path 6               
* greet
  - utter_greet 
* query_attend_per_organisation{"Organisation":"Chamber of commerce"} 
  - utter_action_query_attend_per_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye


## path 7               
* greet
  - utter_greet 
* query_attend_organisation{"Organisation":"CCIMC"} 
  - utter_action_query_attend_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye
 
## path 8               
* greet
  - utter_greet 
* query_attend_per_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_attend_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye

## path 9               
* greet
  - utter_greet 
* query_attend_organisation{"Organisation":"Chamber of Commerce"} 
  - utter_action_query_attend_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
  
## path 10               
* greet
  - utter_greet 
* query_infoattend_organisation{"Organisation":"Chamber of Commerce"} 
  - utter_action_query_infoattend_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
   

## path 11               
* greet
  - utter_greet 
* query_infoattend_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_infoattend_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
  
  
## path 12               
* greet
  - utter_greet 
* query_infoattend_organisation{"Organisation":"CCIMC"} 
  - utter_action_query_infoattend_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 

## path 13              
* greet
  - utter_greet 
* query_join_organisation{"Organisation":"Chamber of Commerce"} 
  - utter_action_query_join_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
  
## path 14               
* greet
  - utter_greet 
* query_join_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_join_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
   

## path 15               
* greet
  - utter_greet 
* query_join_organisation{"Organisation":"CCIMC"} 
  - utter_action_query_join_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 

## path 16             
* greet
  - utter_greet 
* query_services_organisation{"Organisation":"Chamber of Commerce"} 
  - utter_action_query_services_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
  
## path 17               
* greet
  - utter_greet 
* query_services_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_services_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
   

## path 18              
* greet
  - utter_greet 
* query_services_organisation{"Organisation":"CCIMC"} 
  - utter_action_query_services_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 


## path 19              
* greet
  - utter_greet 
* query_location_organisation{"Organisation":"Chamber of Commerce"} 
  - utter_action_query_location_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
  
## path 20               
* greet
  - utter_greet 
* query_location_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_location_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
   

## path 21              
* greet
  - utter_greet 
* query_location_organisation{"Organisation":"CCIMC"} 
  - utter_action_query_location_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 


## path 22             
* greet
  - utter_greet 
* query_document1_organisation{"Organisation":"Chamber of Commerce"} 
  - utter_action_query_document1_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
  
## path 23               
* greet
  - utter_greet 
* query_document1_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_document1_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
   

## path 24              
* greet
  - utter_greet 
* query_document1_organisation{"Organisation":"CCIMC"} 
  - utter_action_query_document1_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 

## path 25           
* greet
  - utter_greet 
* query_document2_organisation{"Organisation":"Chamber of Commerce"} 
  - utter_action_query_document2_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
  
## path 26               
* greet
  - utter_greet 
* query_document2_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_document2_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
   

## path 27              
* greet
  - utter_greet 
* query_document2_organisation{"Organisation":"CCIMC"} 
  - utter_action_query_document2_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 

## path 28           
* greet
  - utter_greet 
* query_offeerdocument1_organisation{"Organisation":"Chamber of Commerce"} 
  - utter_action_query_offeerdocument1_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
  
## path 29               
* greet
  - utter_greet 
* query_offeerdocument1_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_offeerdocument1_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
   

## path 30             
* greet
  - utter_greet 
* query_offeerdocument1_organisation{"Organisation":"CCIMC"} 
  - utter_action_query_offeerdocument1_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 

## path 31           
* greet
  - utter_greet 
* query_invest_organisation{"Organisation":"Chamber of Commerce"} 
  - utter_action_query_invest_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
  
## path 32               
* greet
  - utter_greet 
* query_invest_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_invest_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
   

## path 33             
* greet
  - utter_greet 
* query_invest_organisation{"Organisation":"CCIMC"} 
  - utter_action_query_invest_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 


## path 32           
* greet
  - utter_greet 
* query_economic{"Organisation":"Chamber of Commerce"} 
  - utter_action_query_economic
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
  
## path 35            
* greet
  - utter_greet 
* query_economic{"Organisation":"CCIMA"} 
  - utter_action_query_economic
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
   

## path 36             
* greet
  - utter_greet 
* query_economic{"Organisation":"CCIMC"} 
  - utter_action_query_economic
* affirm 
  - utter_affirm
* bye 
  - utter_bye 

## path 37           
* greet
  - utter_greet 
* query_support{"Organisation":"Chamber of Commerce"} 
  - utter_action_query_support
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
  
## path 38            
* greet
  - utter_greet 
* query_support{"Organisation":"CCIMA"} 
  - utter_action_query_support
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
   

## path 39             
* greet
  - utter_greet 
* query_support{"Organisation":"CCIMC"} 
  - utter_action_query_support
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
  
## path 40              
* greet
  - utter_greet 
* query_list_organisation{"Organisation":"Chamber of Commerce"} 
  - utter_action_query_list_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
  
## path 41               
* greet
  - utter_greet 
* query_list_organisation{"Organisation":"CCIMA"} 
  - utter_action_query_list_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 
   

## path 42               
* greet
  - utter_greet 
* query_list_organisation{"Organisation":"CCIMC"} 
  - utter_action_query_list_organisation
* affirm 
  - utter_affirm
* bye 
  - utter_bye 

 
 """

# %store stories_md > stories.md
# Out:
# Writing 'stories_md' (str) to file 'stories.md'.

# %% [markdown]
#  In the next step we will create a file call domain which will contain all the file of the responses of the chatbot

# %%
domain_yml = """
intents:
- greet
- query_list_organisation
- affirm
- query_support
- data
- query_offeerdocument1_organisation
- query_invest_organisation
- query_attend_per_organisation
- query_services_organisation
- query_economic
- query_infoattend_organisation
- query_document1_organisation
- query_organisation
- query_helping
- greet
- bye
- location
- query_join_organisation
- occurence
- query_document2_organisation
- query_location_organisation
- query_join_organisation
- query_attend_organisation
- query_support
- query_list_organisation

slots:
  Organisation:
    type: categorical
    values:
        - Chamber of commerce
        - chambre de commerce
        - CCIMA
        - ccima
        - CCIMC
        - ccimc
        - Cameroon chamber of commerce
        - Chamber of Commerce,Industry, Mines and Crafts
  country:
    type: categorical
    values:
        - Cameroon
        - cameroon
  meeting:
    type: categorical
    values:
        - meeting
        - gathering
        - conference
        - congregation
        - convocation
        - conclave
        - convention
        - summit
        - forum
        - conference
        - gathering
  document:
    type: categorical
    values:
        - Certificate of origin
        - certificate of origin
        - Consular file
        - consular file     
  person:
    type: categorical
    values:
        - investors
  occurence:
    type: categorical
    values:
        - events
        - contest
        - affair
        - business
        - occassion
        - occurence
  data:
    type: categorical
    values:
        - information
        
entities:
- data
- occurence
- person
- meeting
- country
- Organisation
- document


actions:
- utter_greet
- utter_action_query_organisation
- utter_action_query_attend_per_organisation
- utter_action_query_attend_organisation
- utter_action_query_infoattend_organisation
- utter_action_query_join_organisation
- utter_action_query_list_organisation 
- utter_action_query_services_organisation
- utter_action_query_location_organisation
- utter_action_query_document1_organisation
- utter_action_query_document2_organisation
- utter_action_query_offeerdocument1_organisation
- utter_action_query_invest_organisation 
- utter_action_query_economic
- utter_action_query_support
- utter_bye
- utter_affirm
- __main__.ApiAction

templates:
  utter_greet:
  - text: Hello,I am the AIMS-bot how may I help You 
  utter_action_query_organisation:
  - text: The chamber of commerce, industries, mining and crafting is a national consultative and representative body at the national services of the entire Cameroon enterprises sector. The Chamber represents and promotes members of the organization. It identifies community problems and issues affecting businesses and provides leadership to solve these problems. In this way, the Chamber accomplishes collectively what no business can do alone.
  utter_action_query_attend_per_organisation:
  - text: Anyone who is employed by a member company is eligible to attend Chamber events at member discount prices. Our events are also open to the general public for a non-member rate   
  utter_action_query_attend_organisation:
  - text: Anyone who is employed by a member company is eligible to attend Chamber events at member discount prices. Our events are also open to the general public for a non-member rate 
  utter_action_query_infoattend_organisation:
  - text: it is possible to information through the chamber of commerce website WWW.ccima.cm and if you are already register for the event you will be notified by email or through call      
  utter_action_query_join_organisation:
  - text: Any business institution can join the chamber of commerce, to so you have be register to their membership through the consular file       
  utter_action_query_list_organisation:
  - text: To get the list of the business at the chamber of commerce and what they do you have to the chamber of commerce"
  utter_action_query_services_organisation:
  - text: They offer may services.such as vocational training, economic information, support for companies, promotion and conquest of the markets, orga- nization of trade fairs, auction sales of discarded goods, opinion on draft laws and
         regulations relating to commercial economic activities, creation, regulation, opera- tion or abolition of stock and trade exchanges, issuance of the certificate of origin.
  utter_action_query_location_organisation:
  - text: The Chamber of commerce is lacated at Bonanjo in Douala and have a delegation in all the region of Cameroon
  utter_action_query_document1_organisation:
  - text: To have every information o the consular file use the link http://www.ccima.cm/index.php/espace-entreprises/le-fichier-consulaire
  utter_action_query_document2_organisation:
  - text: it is a document certifying that the goods in an export shipment in particular,are wholly obtained, produced, manufactured or processed in a country, or it is a document that identifies a good through a country or
          group of countries that has contributed to its transformation into a finished p0roduct.
  utter_action_query_offeerdocument1_organisation:
  - text: The chamber of commerce in charge of offering certifcate of origin and can be done also online
  utter_action_query_economic:
  - text: This is an information is got through the website of the CCIMA-www.ccima.cm
  utter_action_query_support:
  - text: The chamber of commerce can support people who want to creat their industry
  utter_action_query_invest_organisation:
  - text: In order to access the investor opportunities http://www.ccima.cm/index.php/investir-au-cameroun/les-opportunites-d-investissement
  utter_affirm:
  - text: You're welcome
  utter_bye:
  - text: Good bye I hope I have been of great help for more information contact nteupejoelrostand@gmail.com 
  
"""

# %store domain_yml > domain.yml
# Out:
# Writing 'domain_yml' (str) to file 'domain.yml'.

# %% [markdown]
# Here will create an action telling the bot to deal with some situation

# %%
custom_action = """

from rasa_core.actions import Action
from rasa_core.events import SlotSet
class GetTodaysHoroscope((Action):
   def name(self):
      return "hi"
   def run(self, dispatcher, tracker, domain):
      # type: (Dispatcher, DialogueStateTracker, Domain) -> List[Event]
      user_horoscope_sign = tracker.get_slot('horoscope_sign')
return [SlotSet("horoscope_sign", user_horoscope_sign)]
"""
# %store custom_action > actions.py
# Out:
# Writing 'custom_action' (str) to file 'actions.py'.

# %%
custom_action = """
from __future__ import absolute_import
from __future__ import division 
from __future__ import print_function
from __future__ import unicode_literals

from rasa_core_sdk import Action
from rasa_core_sdk.events import SlotSet
class GetTodaysHoroscope(Action):
    def name(self):
        return "get_todays_horoscope"
    def run(self, dispatcher, tracker, domain):
        # type: (Dispatcher, DialogueStateTracker, Domain) -> List[Event]
        user_horoscope_sign = tracker.get_slot('horoscope_sign')
        base_url = http://horoscope-api.herokuapp.com/horoscope/{day}/{sign}
        url = base_url.format(**{'day': "today", 'sign': user_horoscope_
sign})
        #http://horoscope-api.herokuapp.com/horoscope/today/capricorn
        res = requests.get(url)
        todays_horoscope = res.json()['horoscope']
        response = "Your today's horoscope:\n{}".format(todays_horoscope)
        dispatcher.utter_message(response)
        return [SlotSet("horoscope_sign", user_horoscope_sign)]
"""
# %store custom_action > custome_actions.py
# Out:
# Writing 'custom_action' (str) to file 'custome_actions.py'.

# %%
#from __future__ import absolute_import
#from __future__ import division
#from __future__ import print_function
#from __future__ import uicode_literals

#from rasa_core import utils
#from rasa_core.agent import Agent
#from rasa_core.policies.keras_policy import KerasPolicy
#from rasa_core.policies.memoization import MemoizationPolicy
#from rasa_core.policies.sklearn_policy import SklearnPolicy
#if __name__ == '__main__':
   #utils.configure_colored_logging(loglevel="DEBUG")
    #training_data_file = './data/stories.md'
    #model_path = './models/nlu'
    #agent.train(
            #training_data,
            #augmentation_factor=50,
            #epochs=500,
            #batch_size=10,
            #validation_split=0.2
    #)
    #agent.persist(model_path)

# %%
The test code to add another policy

# %%
import logging
import rasa_core

from rasa_core.policies.keras_policy import KerasPolicy
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
            Masking,
            LSTM,
            Dense,
            TimeDistributed,
            Activation,
        )

logger = logging.getLogger(__name__)


class SeqToSeqPolicy(KerasPolicy):
    def model_architecture(self, input_shape, output_shape):
        # Build Model
        model = Sequential()

        # the shape of the y vector of the labels,
        # determines which output from rnn will be used
        # to calculate the loss
        if len(output_shape) == 1:
            # y is (num examples, num features) so
            # only the last output from the rnn is used to
            # calculate the loss
            model.add(Masking(mask_value=-1, input_shape=input_shape))
            model.add(LSTM(self.rnn_size))
            model.add(Dense(input_dim=self.rnn_size, units=output_shape[-1]))
        elif len(output_shape) == 2:
            # y is (num examples, max_dialogue_len, num features) so
            # all the outputs from the rnn are used to
            # calculate the loss, therefore a sequence is returned and
            # time distributed layer is used

            # the first value in input_shape is max dialogue_len,
            # it is set to None, to allow dynamic_rnn creation
            # during prediction
            model.add(Masking(mask_value=-1, input_shape=(None, input_shape[1])))
            model.add(LSTM(self.rnn_size, return_sequences=True))
            model.add(TimeDistributed(Dense(units=output_shape[-1])))
        else:
            raise ValueError(
                "Cannot construct the model because"
                "length of output_shape = {} "
                "should be 1 or 2."
                "".format(len(output_shape))
            )

        model.add(Activation("softmax"))

        model.compile(
            loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
        )

        logger.debug(model.summary())
        return model

# %% [markdown]
# Here we will going to train the rasa core agent for the dialogue management
#
# We are going to show Rasa Core the stories we wrote above, and train a model.
#
# In this case, the model is a neural network implemented in Keras which learns to predict which action to take next. The default architecture is based on an LSTM.

# %% [markdown]
# policies:
#   - name: KerasPolicy;
#     epochs: 100,
#     validation_splits=0.0,
#     max_history: 5
#   - name: FallbackPolicy;
#     fallback_action_name: 'action_default_fallback'
#   - name: MemoizationPolicy;
#     max_history: 5
#
#     Keraspolicy which uses LSTM since it is embedded already with Rasa

# %%
from rasa_core.policies import KerasPolicy, MemoizationPolicy
from rasa_core.agent import Agent

# there is a threshold for the NLU predictions as well as the action predictions
agent = Agent('domain.yml', policies=[MemoizationPolicy(), KerasPolicy(epochs=1300)])
# loading our neatly defined training dialogues
training_data = agent.load_data('stories.md')

agent.train(
    training_data
)

agent.persist('models/dialogue')
# Out:
# Processed Story Blocks:   0%|          | 0/42 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Processed Story Blocks:   0%|          | 0/42 [00:00<?, ?it/s, # trackers=1]
#
#
#
#
#
#
#
#
# Processed Story Blocks:   0%|          | 0/42 [00:00<?, ?it/s, # trackers=1]
#
#
#
#
#
#
#
#
# Processed Story Blocks:   0%|          | 0/42 [00:00<?, ?it/s, # trackers=1]
#
#
#
#
#
#
#
#
# Processed Story Blocks:   0%|          | 0/42 [00:00<?, ?it/s, # trackers=1]
#
#
#
#
#
#
#
#
# Processed Story Blocks:   0%|          | 0/42 [00:00<?, ?it/s, # trackers=1]
#
#
#
#
#
#
#
#
# Processed Story Blocks:   0%|          | 0/42 [00:00<?, ?it/s, # trackers=1]
#
#
#
#
#
#
#
#
# Processed Story Blocks:   0%|          | 0/42 [00:00<?, ?it/s, # trackers=1]
#
#
#
#
#
#
#
#
# Processed Story Blocks:   0%|          | 0/42 [00:00<?, ?it/s, # trackers=1]
#
#
#
#
#
#
#
#
# Processed Story Blocks:   0%|          | 0/42 [00:00<?, ?it/s, # trackers=1]
#
#
#
#
#
#
#
#
# ...

# %% [markdown]
# we will go on and test the bot
#
#
# from the previous training we can see that the dialogue with continuos training will reach near 1

# %%
from rasa_core.agent import Agent
# we can also use the RASANLU intepreter to help that to use our interpreter that is model_directory, use from rasa_core.interpreter import RasaNLUInterpreter
agent = Agent.load('models/dialogue', interpreter=model_directory)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
# INFO:rasa_nlu.components:Added 'SpacyNLP' to component cache. Key 'SpacyNLP-en_core_web_md'.

# %% [markdown]
# Here will start a conversation with the bot

# %%
print("Your bot is ready to talk! Type your messages here or send 'stop'")
while True:
    a = input()
    if a == 'stop':
        break
    responses = agent.handle_text(a)
    # responses = agent.handle_message(a)
    for response in responses:
        print(response["text"])
# Out:
# Your bot is ready to talk! Type your messages here or send 'stop'
# hi
# Hello,I am the AIMS-bot how may I help You
# what do the ccima do?
# The chamber of commerce, industries, mining and crafting is a national consultative and representative body at the national services of the entire Cameroon enterprises sector. The Chamber represents and promotes members of the organization. It identifies community problems and issues affecting businesses and provides leadership to solve these problems. In this way, the Chamber accomplishes collectively what no business can do alone.
# thanks
# You're welcome
# bye
# Good bye I hope I have been of great help for more information contact nteupejoelrostand@gmail.com
# where is the chamber of commerce located
# Hello,I am the AIMS-bot how may I help You
# what
# Anyone who is employed by a member company is eligible to attend Chamber events at member discount prices. Our events are also open to the general public for a non-member rate
# hein
# ...
